# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
austin_pop_df = pd.read_csv("Data/AustinZipCodePopulation.csv")
austin_pop_df.head(3)
# Out:
#    Zipcode  2015_Population  2016_Population  2017_Population  2018_Population
# 0    78681            54923            56086            57234            58665
# 1    78701             7051             7401             7875             8072
# 2    78702            21477            22617            22876            23448

# %%
population = []

# %%
population.append(austin_pop_df["2015_Population"].sum())
population.append(austin_pop_df["2016_Population"].sum())
population.append(austin_pop_df["2017_Population"].sum())
population.append(austin_pop_df["2018_Population"].sum())

# %%
years = ["2015_Austin", "2016_Austin", "2017_Austin", "2018_Austin"]
x_axis = np.arange(len(years))

# %%
plt.bar(x_axis, population, color="b", align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, years)
# Out:
# ([<matplotlib.axis.XTick at 0x117dfc898>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
plt.savefig("Figures/Austin_Population_Bar_Chart")

# %%
plt.show()

# %%
two_year_df = austin_pop_df[["2015_Population", "2018_Population"]]

# %%
multi_plot = two_year_df.plot(kind="bar", figsize=(10,5))
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
multi_plot.set_xticklabels(austin_pop_df["Zipcode"], rotation = 90)
# Out:
# [Text(0, 0, '78681'),
#  Text(1, 0, '78701'),
#  Text(2, 0, '78702'),
#  Text(3, 0, '78703'),
#  Text(4, 0, '78704'),
#  Text(5, 0, '78705'),
#  Text(6, 0, '78712'),
#  Text(7, 0, '78717'),
#  Text(8, 0, '78719'),
#  Text(9, 0, '78721'),
#  Text(10, 0, '78722'),
#  Text(11, 0, '78723'),
#  Text(12, 0, '78724'),
#  Text(13, 0, '78725'),
#  Text(14, 0, '78726'),
#  Text(15, 0, '78727'),
#  Text(16, 0, '78728'),
#  Text(17, 0, '78729'),
#  Text(18, 0, '78730'),
#  Text(19, 0, '78731'),
#  Text(20, 0, '78732'),
#  Text(21, 0, '78733'),
#  Text(22, 0, '78734'),
#  Text(23, 0, '78735'),
#  Text(24, 0, '78736'),
#  Text(25, 0, '78737'),
#  Text(26, 0, '78738'),
#  Text(27, 0, '78739'),
#  Text(28, 0, '78741'),
#  Text(29, 0, '78742'),
#  Text(30, 0, '78744'),
#  Text(31, 0, '78745'),
#  Text(32, 0, '78746'),
#  Text(33, 0, '78747'),
#  Text(34, 0, '78748'),
#  Text(35, 0, '78749'),
#  Text(36, 0, '78750'),
#  Text(37, 0, '78751'),
#  Text(38, 0, '78752'),
#  Text(39, 0, '78753'),
# ...

# %%
plt.show()
plt.tight_layout()
plt.savefig("Figures/2015_and_2018_barChart")
